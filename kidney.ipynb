# %% [markdown]
# load kidney dataset

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\ABIRAINA\OneDrive\Desktop\guvi_project\miniproject4\kidney_disease - kidney_disease.csv")
display(data)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
data.shape
# Out:
# (400, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %% [markdown]
# check for missing data

# %%
# Check for missing values in each column
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
import numpy as np
# Example: for numerical columns (use mean)
numerical_cols = ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']
for col in numerical_cols:
    data[col] = data[col].fillna(data[col].mean())

# For categorical columns (use mode)
categorical_cols = ['rbc', 'pc', 'pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
for col in categorical_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
print(data.isnull().sum())
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
display(data)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
to_numeric = ['pcv', 'wc', 'rc']
for col in to_numeric:
    data[col] = pd.to_numeric(data[col], errors='coerce')  # Convert and coerce errors to NaN

# Re-fill new NaNs
for col in to_numeric:
    data[col] = data[col].fillna(data[col].mean())

# %%
# Encode categorical variables
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for col in data.select_dtypes(include="object").columns:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
X =data.drop("classification",axis=1)
y =data['classification']
model = DecisionTreeClassifier()
model.fit(X, y)

feature_importance = pd.Series(model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False).head(7)
# Out:
# id     1.0
# age    0.0
# bp     0.0
# sg     0.0
# al     0.0
# su     0.0
# rbc    0.0
# dtype: float64

# %%
# Features and target
X = data[['id','age', 'bp', 'sg', 'al', 'su', 'rbc']]
y = data["classification"]

# %%
# Scale features 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
y_train.value_counts()
# Out:
# classification
# 0    174
# 1    106
# Name: count, dtype: int64

# %%
# Apply SMOTE to balance the training data
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(X_train_bal,y_train_bal)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9666666666666667
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.95      0.95      0.95        44
#
#     accuracy                           0.97       120
#    macro avg       0.96      0.96      0.96       120
# weighted avg       0.97      0.97      0.97       120

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train_bal,y_train_bal)
y_pred=dt.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9916666666666667
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        76
#            1       1.00      0.98      0.99        44
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# Plot ROC Curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
y_proba = dt.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
print("ROC AUC Score:", roc_auc_score(y_test, y_proba))
plt.figure()
plt.plot(fpr, tpr, label=f"Decisiontree (AUC = {roc_auc_score(y_test, y_proba):.2f})", color='purple')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(" Decisiontree- ROC Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# ROC AUC Score: 0.9886363636363636

# %%
# Plot Confusion Matrix
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_estimator(dt, X_test, y_test, cmap="Purples")
plt.title("Decisiontree - Confusion Matrix")
plt.show()

# %%
import pickle
# Save the trained model
with open("decisiontree_model.pkl", "wb") as f:
    pickle.dump(dt, f)
print("Model saved as 'decisiontree_model.pkl'")
# Out:
# Model saved as 'decisiontree_model.pkl'

# %%
# save the scaler
with open('scaler_decisiontree.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("model saved as scaler_decisiontree.pkl")
# Out:
# model saved as scaler_decisiontree.pkl

# %%
# save the encoder
with open('encoder_decisiontree.pkl', 'wb') as f:
    pickle.dump(le, f)
print("model saved as encoder_decisiontree.pkl")
# Out:
# model saved as encoder_decisiontree.pkl
