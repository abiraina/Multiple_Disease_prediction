# %% [markdown]
# load the liver dataset

# %%
# !pip install pandas

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\ABIRAINA\OneDrive\Desktop\guvi_project\miniproject4\indian_liver_patient - indian_liver_patient.csv")
display(data)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
data.shape
# Out:
# (583, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
data.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %% [markdown]
# check for missing values

# %%
# Check for missing values in each column
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %% [markdown]
# fill the missing values(using median)

# %%
data['Albumin_and_Globulin_Ratio'] = data['Albumin_and_Globulin_Ratio'].fillna(data['Albumin_and_Globulin_Ratio'].median())

# %%
# Assuming 'Dataset' is already 1 for disease and 2 for no disease
data['Dataset'] = data['Dataset'].map({1: 1, 2: 0})

# %% [markdown]
# correlation matrix

# %%
# !pip install seaborn matplotlib

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Apply Label Encoding to 'Gender' column only
data['Gender'] = le.fit_transform(data['Gender'])
print(data)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0              0.7               0.1                   187
# 1     62       1             10.9               5.5                   699
# 2     62       1              7.3               4.1                   490
# 3     58       1              1.0               0.4                   182
# 4     72       1              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       1              0.5               0.1                   500
# 579   40       1              0.6               0.1                    98
# 580   52       1              0.8               0.2                   245
# 581   31       1              1.3               0.5                   184
# 582   38       1              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
correlation_matrix = data.corr()

plt.figure(figsize=(6, 5)) # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Features and target
X = data[['Total_Bilirubin','Total_Protiens','Albumin_and_Globulin_Ratio','Alamine_Aminotransferase','Aspartate_Aminotransferase']]
y = data["Dataset"]

# %%
# Scale features 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
y_train.value_counts()
# Out:
# Dataset
# 1    288
# 0    120
# Name: count, dtype: int64

# %%
# Apply SMOTE to balance the training data
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(X_train_bal,y_train_bal)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.6457142857142857
#               precision    recall  f1-score   support
#
#            0       0.42      0.87      0.57        47
#            1       0.92      0.56      0.70       128
#
#     accuracy                           0.65       175
#    macro avg       0.67      0.72      0.63       175
# weighted avg       0.79      0.65      0.66       175

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train_bal,y_train_bal)
y_pred=dt.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.6628571428571428
#               precision    recall  f1-score   support
#
#            0       0.40      0.51      0.45        47
#            1       0.80      0.72      0.76       128
#
#     accuracy                           0.66       175
#    macro avg       0.60      0.61      0.60       175
# weighted avg       0.69      0.66      0.67       175

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)#parameter how many decision tree has to be generator
rf.fit(X_train_bal,y_train_bal)
y_pred=rf.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.6971428571428572
#               precision    recall  f1-score   support
#
#            0       0.46      0.68      0.55        47
#            1       0.86      0.70      0.77       128
#
#     accuracy                           0.70       175
#    macro avg       0.66      0.69      0.66       175
# weighted avg       0.75      0.70      0.71       175

# %%
# Plot ROC Curve
from sklearn.metrics import roc_auc_score, roc_curve
y_proba = rf.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
print("ROC AUC Score:", roc_auc_score(y_test, y_proba))
plt.figure()
plt.plot(fpr, tpr, label=f"RandomForest (AUC = {roc_auc_score(y_test, y_proba):.2f})", color='purple')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(" RandomForest- ROC Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# ROC AUC Score: 0.7285571808510638

# %%
# Plot Confusion Matrix
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, cmap="Purples")
plt.title("RandomForest - Confusion Matrix")
plt.show()

# %%
import pickle
# Save the trained model
with open("randomforest_model.pkl", "wb") as f:
    pickle.dump(rf, f)
print("Model saved as 'randomforest_model.pkl'")
# Out:
# Model saved as 'randomforest_model.pkl'

# %%
# Save both
with open('scaler_randomforest.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
with open('encoder_randomforest.pkl', 'wb') as f:
    pickle.dump(le, f)
